# %% [markdown]
# ### A test
# This is a test. Run the following:

# %%
import plex

# %% [markdown]
# If no error, we are ok.
#
# Από τη «Θεωρία Υπολογισμού»: Κάθε αυτόματο πεπερασμένων καταστάσεων (*finite automaton –FA*) είναι μια πεντάδα $(Q, \Sigma, \delta, q_0, F)$
